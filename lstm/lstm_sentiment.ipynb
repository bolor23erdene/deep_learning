# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchtext
import tqdm
import torch


from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import DataLoader

# %%
torch.__version__, torchtext.__version__
# Out:
# ('1.11.0', '0.12.0')

# %% [markdown]
# # PREPROCESSING

# %% [markdown]
# ### 1. iterators and tokenizers

# %%
# class AG_NEWS from torchtext.datasets 
from torchtext.datasets import AG_NEWS
train_iter = AG_NEWS(split='train')

# %%
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

tokenizer = get_tokenizer('basic_english')
train_iter = AG_NEWS(split='train')

def yield_tokens(data_iter):
    for _, text in data_iter:
        yield tokenizer(text)

vocab = build_vocab_from_iterator(yield_tokens(train_iter), specials=["<unk>"])
vocab.set_default_index(vocab["<unk>"])
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=701'>702</a> # Make the request on the httplib connection object.
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=702'>703</a> httplib_response = self._make_request(
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=703'>704</a>     conn,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=704'>705</a>     method,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=705'>706</a>     url,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=706'>707</a>     timeout=timeout_obj,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=707'>708</a>     body=body,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=708'>709</a>     headers=headers,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=709'>710</a>     chunked=chunked,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=710'>711</a> )
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=712'>713</a> # If we're going to release the connection in ``finally:``, then
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=713'>714</a> # the response doesn't need to know about the connection. Otherwise
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=714'>715</a> # it will also try to release it and we'll have a double-release
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=715'>716</a> # mess.
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=384'>385</a> try:
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=385'>386</a>     self._validate_conn(conn)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=386'>387</a> except (SocketTimeout, BaseSSLError) as e:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=387'>388</a>     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py:1040, in HTTPSConnectionPool._validate_conn(self, conn)
#    <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=1038'>1039</a> if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=1039'>1040</a>     conn.connect()
#    <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=1041'>1042</a> if not conn.is_verified:
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=411'>412</a>     context.load_default_certs()
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=413'>414</a> self.sock = ssl_wrap_socket(
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=414'>415</a>     sock=conn,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=415'>416</a>     keyfile=self.key_file,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=416'>417</a>     certfile=self.cert_file,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=417'>418</a>     key_password=self.key_password,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=418'>419</a>     ca_certs=self.ca_certs,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=419'>420</a>     ca_cert_dir=self.ca_cert_dir,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=420'>421</a>     ca_cert_data=self.ca_cert_data,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=421'>422</a>     server_hostname=server_hostname,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=422'>423</a>     ssl_context=context,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=423'>424</a>     tls_in_tls=tls_in_tls,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=424'>425</a> )
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=426'>427</a> # If we're using all defaults and the connection
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=427'>428</a> # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connection.py?line=428'>429</a> # for the host.
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/ssl_.py?line=447'>448</a> if send_sni:
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/ssl_.py?line=448'>449</a>     ssl_sock = _ssl_wrap_socket_impl(
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/ssl_.py?line=449'>450</a>         sock, context, tls_in_tls, server_hostname=server_hostname
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/ssl_.py?line=450'>451</a>     )
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/ssl_.py?line=451'>452</a> else:
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/ssl_.py?line=491'>492</a> if server_hostname:
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/ssl_.py?line=492'>493</a>     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/ssl_.py?line=493'>494</a> else:
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=493'>494</a> def wrap_socket(self, sock, server_side=False,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=494'>495</a>                 do_handshake_on_connect=True,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=495'>496</a>                 suppress_ragged_eofs=True,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=496'>497</a>                 server_hostname=None, session=None):
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=497'>498</a>     # SSLSocket class handles server_hostname encoding before it calls
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=498'>499</a>     # ctx._wrap_socket()
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=499'>500</a>     return self.sslsocket_class._create(
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=500'>501</a>         sock=sock,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=501'>502</a>         server_side=server_side,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=502'>503</a>         do_handshake_on_connect=do_handshake_on_connect,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=503'>504</a>         suppress_ragged_eofs=suppress_ragged_eofs,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=504'>505</a>         server_hostname=server_hostname,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=505'>506</a>         context=self,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=506'>507</a>         session=session
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=507'>508</a>     )
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=1038'>1039</a>             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=1039'>1040</a>         self.do_handshake()
#    <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=1040'>1041</a> except (OSError, ValueError):
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=1307'>1308</a>         self.settimeout(None)
# -> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=1308'>1309</a>     self._sslobj.do_handshake()
#    <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/ssl.py?line=1309'>1310</a> finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=438'>439</a> if not chunked:
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=439'>440</a>     resp = conn.urlopen(
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=440'>441</a>         method=request.method,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=441'>442</a>         url=url,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=442'>443</a>         body=request.body,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=443'>444</a>         headers=request.headers,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=444'>445</a>         redirect=False,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=445'>446</a>         assert_same_host=False,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=446'>447</a>         preload_content=False,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=447'>448</a>         decode_content=False,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=448'>449</a>         retries=self.max_retries,
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=449'>450</a>         timeout=timeout
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=450'>451</a>     )
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=452'>453</a> # Send the request.
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=453'>454</a> else:
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=782'>783</a>     e = ProtocolError("Connection aborted.", e)
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=784'>785</a> retries = retries.increment(
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=785'>786</a>     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=786'>787</a> )
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/connectionpool.py?line=787'>788</a> retries.sleep()
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/retry.py?line=590'>591</a> if new_retry.is_exhausted():
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/retry.py?line=591'>592</a>     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/urllib3/util/retry.py?line=593'>594</a> log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='raw.githubusercontent.com', port=443): Max retries exceeded with url: /mhjabreel/CharCnn_Keras/master/data/ag_news_csv/train.csv (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py:17, in _get_response_from_http(url, timeout)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=15'>16</a> if timeout is None:
# ---> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=16'>17</a>     r = session.get(url, stream=True)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=17'>18</a> else:
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py:542, in Session.get(self, url, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py?line=540'>541</a> kwargs.setdefault('allow_redirects', True)
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py?line=541'>542</a> return self.request('GET', url, **kwargs)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py?line=527'>528</a> send_kwargs.update(settings)
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py?line=528'>529</a> resp = self.send(prep, **send_kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py?line=530'>531</a> return resp
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py?line=643'>644</a> # Send the request
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py?line=644'>645</a> r = adapter.send(request, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/sessions.py?line=646'>647</a> # Total elapsed time of the request (approximately)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py:517, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=514'>515</a> if isinstance(e.reason, _SSLError):
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=515'>516</a>     # This branch is for urllib3 v1.22 and later.
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=516'>517</a>     raise SSLError(e, request=request)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/requests/adapters.py?line=518'>519</a> raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='raw.githubusercontent.com', port=443): Max retries exceeded with url: /mhjabreel/CharCnn_Keras/master/data/ag_news_csv/train.csv (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)')))
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb Cell 2' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb#ch0000001?line=7'>8</a>     for _, text in data_iter:
#       <a href='vscode-notebook-cell:/Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb#ch0000001?line=8'>9</a>         yield tokenizer(text)
# ---> <a href='vscode-notebook-cell:/Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb#ch0000001?line=10'>11</a> vocab = build_vocab_from_iterator(yield_tokens(train_iter), specials=["<unk>"])
#      <a href='vscode-notebook-cell:/Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb#ch0000001?line=11'>12</a> vocab.set_default_index(vocab["<unk>"])
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchtext/vocab/vocab_factory.py:92, in build_vocab_from_iterator(iterator, min_freq, specials, special_first, max_tokens)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchtext/vocab/vocab_factory.py?line=65'>66</a> """
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchtext/vocab/vocab_factory.py?line=66'>67</a> Build a Vocab from an iterator.
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchtext/vocab/vocab_factory.py?line=67'>68</a>
#    (...)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchtext/vocab/vocab_factory.py?line=87'>88</a>     >>> vocab = build_vocab_from_iterator(yield_tokens(file_path), specials=["<unk>"])
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchtext/vocab/vocab_factory.py?line=88'>89</a> """
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchtext/vocab/vocab_factory.py?line=90'>91</a> counter = Counter()
# ---> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchtext/vocab/vocab_factory.py?line=91'>92</a> for tokens in iterator:
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchtext/vocab/vocab_factory.py?line=92'>93</a>     counter.update(tokens)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchtext/vocab/vocab_factory.py?line=94'>95</a> specials = specials or []
#
# /Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb Cell 2' in yield_tokens(data_iter)
#       <a href='vscode-notebook-cell:/Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb#ch0000001?line=6'>7</a> def yield_tokens(data_iter):
# ----> <a href='vscode-notebook-cell:/Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb#ch0000001?line=7'>8</a>     for _, text in data_iter:
#       <a href='vscode-notebook-cell:/Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb#ch0000001?line=8'>9</a>         yield tokenizer(text)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py:112, in MapperIterDataPipe.__iter__(self)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py?line=110'>111</a> def __iter__(self) -> Iterator[T_co]:
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py?line=111'>112</a>     for data in self.datapipe:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py?line=112'>113</a>         yield self._apply_fn(data)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py:148, in _CSVBaseParserIterDataPipe.__iter__(self)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py?line=146'>147</a> def __iter__(self) -> Iterator[Union[D, Tuple[str, D]]]:
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py?line=147'>148</a>     for path, file in self.source_datapipe:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py?line=148'>149</a>         stream = self._helper.skip_lines(file)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py?line=149'>150</a>         stream = self._helper.decode(stream)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/fileopener.py:60, in FileOpenerIterDataPipe.__iter__(self)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/fileopener.py?line=58'>59</a> def __iter__(self):
# ---> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/fileopener.py?line=59'>60</a>     yield from get_file_binaries_from_pathnames(self.datapipe, self.mode, self.encoding)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/utils/common.py:85, in get_file_binaries_from_pathnames(pathnames, mode, encoding)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/utils/common.py?line=81'>82</a> if mode in ('b', 't'):
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/utils/common.py?line=82'>83</a>     mode = 'r' + mode
# ---> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/utils/common.py?line=84'>85</a> for pathname in pathnames:
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/utils/common.py?line=85'>86</a>     if not isinstance(pathname, str):
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/utils/common.py?line=86'>87</a>         raise TypeError("Expected string type for pathname, but got {}"
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/utils/common.py?line=87'>88</a>                         .format(type(pathname)))
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/combining.py:46, in ConcaterIterDataPipe.__iter__(self)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/combining.py?line=43'>44</a> def __iter__(self) -> Iterator:
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/combining.py?line=44'>45</a>     for dp in self.datapipes:
# ---> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/combining.py?line=45'>46</a>         for data in dp:
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/combining.py?line=46'>47</a>             yield data
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/saver.py:48, in SaverIterDataPipe.__iter__(self)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/saver.py?line=46'>47</a> def __iter__(self) -> Iterator[str]:
# ---> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/saver.py?line=47'>48</a>     for filepath, data in self.source_datapipe:
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/saver.py?line=48'>49</a>         if self.fn is not None:
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/saver.py?line=49'>50</a>             filepath = self.fn(filepath)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/hashchecker.py:62, in HashCheckerIterDataPipe.__iter__(self)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/hashchecker.py?line=60'>61</a> def __iter__(self) -> Iterator[Tuple[str, StreamWrapper]]:
# ---> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/hashchecker.py?line=61'>62</a>     for file_name, data in self.source_datapipe:
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/hashchecker.py?line=62'>63</a>         if self.hash_type == "sha256":
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/util/hashchecker.py?line=63'>64</a>             hash_func = hashlib.sha256()
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py:112, in MapperIterDataPipe.__iter__(self)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py?line=110'>111</a> def __iter__(self) -> Iterator[T_co]:
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py?line=111'>112</a>     for data in self.datapipe:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py?line=112'>113</a>         yield self._apply_fn(data)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py:112, in MapperIterDataPipe.__iter__(self)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py?line=110'>111</a> def __iter__(self) -> Iterator[T_co]:
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py?line=111'>112</a>     for data in self.datapipe:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/datapipes/iter/callable.py?line=112'>113</a>         yield self._apply_fn(data)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py:366, in hook_iterator.<locals>.wrap_generator(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=363'>364</a> try:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=364'>365</a>     with context():
# --> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=365'>366</a>         response = gen.send(None)
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=366'>367</a>     while True:
#     <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/utils/data/_typing.py?line=367'>368</a>         request = yield response
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py:56, in HTTPReaderIterDataPipe.__iter__(self)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=53'>54</a> def __iter__(self) -> Iterator[Tuple[str, StreamWrapper]]:
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=54'>55</a>     for url in self.source_datapipe:
# ---> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=55'>56</a>         yield _get_response_from_http(url, timeout=self.timeout)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py:24, in _get_response_from_http(url, timeout)
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=21'>22</a>     raise Exception(f"Could not get the file. [HTTP Error] {e.response}.")
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=22'>23</a> except RequestException as e:
# ---> <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=23'>24</a>     raise Exception(f"Could not get the file at {url}. [RequestException] {e.response}.")
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=24'>25</a> except Exception:
#      <a href='file:///opt/anaconda3/envs/pytorch/lib/python3.9/site-packages/torchdata/datapipes/iter/load/online.py?line=25'>26</a>     raise
#
# Exception: Could not get the file at https://raw.githubusercontent.com/mhjabreel/CharCnn_Keras/master/data/ag_news_csv/train.csv. [RequestException] None.

# %%
print(tokens[:10]), print(len(tokens))
# Out:
# ['Zentropa', 'has', 'much', 'in', 'common', 'with', 'The', 'Third', 'Man,', 'another']
# 5844680
# (None, None)

# %%
tokenizer = torchtext.data.utils.get_tokenizer('basic_english')

# %%
def tokenize_data(example, tokenizer, max_length):
    tokens = tokenizer(example['text'])[:max_length]
    length = len(tokens)
    return {'tokens': tokens, 'length': length}

# %%
max_length = 256

# train_data = train_data.map(tokenize_data, fn_kwargs={'tokenizer': tokenizer, 'max_length': max_length})
# test_data = test_data.map(tokenize_data, fn_kwargs={'tokenizer': tokenizer, 'max_length': max_length})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb Cell 6' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb#ch0000005?line=0'>1</a> max_length = 256
# ----> <a href='vscode-notebook-cell:/Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb#ch0000005?line=2'>3</a> train_data = train_data.map(tokenize_data, fn_kwargs={'tokenizer': tokenizer, 'max_length': max_length})
#       <a href='vscode-notebook-cell:/Users/bzolbayar/Desktop/git/deep_learning/lstm/lstm_sentiment.ipynb#ch0000005?line=3'>4</a> test_data = test_data.map(tokenize_data, fn_kwargs={'tokenizer': tokenizer, 'max_length': max_length})
#
# NameError: name 'train_data' is not defined
